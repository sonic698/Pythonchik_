# %%
n = int(input("Введите количество чисел N: "))
first_number = float(input("Введите число 1: "))
max_value = first_number
i = 2
while i <= n:
    x = float(input(f"Введите число {i}: "))
    if x > max_value:
        max_value = x
    i = i + 1
print("Максимальное из введённых чисел:", max_value)
# Out:
# Введите количество чисел N:  8
# Введите число 1:  45
# Введите число 2:  97
# Введите число 3:  543
# Введите число 4:  87
# Введите число 5:  54
# Введите число 6:  87
# Введите число 7:  34
# Введите число 8:  654
# Максимальное из введённых чисел: 654.0
