# %%
n = int(input("Введите N: "))
s = 0
i = 1
while i <= n:
    s = s + i   
    i = i + 1   
print("Сумма первых", n, "натуральных чисел:", s)
# Out:
# Введите N:  67
# Сумма первых 67 натуральных чисел: 2278
