# %%
import pandas as pd
df = pd.read_csv('wild_boars.csv')
mod = df.mode().iloc[0]
mod.to_csv('mod_val.csv', header=['Модальное_значение'], encoding='utf-8')

print("Модальные значения:")
print(mod)
print("\nСохранено в 'mod_val.csv'")
# Out:
# Модальные значения:
# boar_id                   1
# gender                 Male
# age_years               5.9
# weight_kg              63.5
# length_cm             210.0
# shoulder_height_cm     80.4
# tusk_length_cm          0.0
# litter_size             0.0
# health_score          100.0
# territory_ha            0.8
# Name: 0, dtype: object
#
# Сохранено в 'mod_val.csv'
