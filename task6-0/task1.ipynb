# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv('wild_boars.csv')

short = df['tusk_length_cm'].min()
long = df['tusk_length_cm'].max()

print("Длина клыков:")
print(df['tusk_length_cm'])
print(f"\nСамые короткие клыки: {short} см")
print(f"Самые длинные клыки: {long} см")
# Out:
# Длина клыков:
# 0       8.9
# 1       2.0
# 2      15.4
# 3      12.5
# 4       9.8
#        ...
# 195    14.7
# 196     1.8
# 197     7.0
# 198     2.7
# 199     0.0
# Name: tusk_length_cm, Length: 200, dtype: float64
#
# Самые короткие клыки: 0.0 см
# Самые длинные клыки: 25.0 см
